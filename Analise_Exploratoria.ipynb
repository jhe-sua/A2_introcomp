# %% [markdown]
# diante dessa imensa quantidade de dados, visualizar eles é um dos principais objetivos
#
# # Ideias de representacoes graficas e tabelas sobre os dados
#
# - Uma serie temporal com a quantidade de bilheteria total por dia, permite ter uma visao geral de como varia a compra de bilheteria ao longo do ano, marcando o dia de maior bilheteria de cada mes FEITO
# - Historiagrama da bilheteria total mensal FEITO
# - Tabela com o ranking dos 10 filmes com mais bilheteria em 2023 FEITO
# - Tabela com o ranring dos 10 filmes com menos bilheteria em 2023 FEITO

# %% [markdown]
# # Funcoes basicas para carregar os dados

# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
def carrega_tabela(database, tabela):
    '''
    Carrega uma tabela de um banco de dados 
    SQLite em um DataFrame do Pandas.
    Parâmetros:
    database: str - Caminho para o arquivo do banco de dados SQLite.
    tabela: str - Nome da tabela a ser carregada.
    '''
    with sqlite3.connect(database) as conn:
        query = f"SELECT * FROM {tabela}"
        df = pd.read_sql_query(query, conn)
    return df

# %%
def lista_tabelas(db_filename):
    '''
    Lista todas as tabelas em um banco de dados SQLite.
    Parâmetros:
    db_filename: str - Caminho para o arquivo do banco de dados SQLite.
    Retorna:
    DataFrame com os nomes das tabelas e suas contagens de linhas.
    '''
    # Connect to the SQLite database
    # conn = sqlite3.connect(db_filename)
    with sqlite3.connect(db_filename) as conn:
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = cursor.fetchall()

        table_row_counts = []
        for table in tables:
            table_name = table[0]
            query = f"SELECT COUNT(*) FROM {table_name};"
            cursor.execute(query)
            row_count = cursor.fetchone()[0]
            table_row_counts.append({"Table": table_name, "Row_Count": row_count})

        return pd.DataFrame(table_row_counts)

# %% [markdown]
# # Navegando os dados

# %%
sessao = carrega_tabela("bilheteria.db", "sessao")
sessao
# Out:
#               id  filme_id  sala_id  publico data_exibicao
# 0              1       253  5004897        8    01/01/2023
# 1              2       253  5001565       15    01/01/2023
# 2              3       253  5001566       14    01/01/2023
# 3              4       253  5003464       23    01/01/2023
# 4              5       253  5001137       37    01/01/2023
# ...          ...       ...      ...      ...           ...
# 1748358  1748359       405  5000331        5    31/12/2023
# 1748359  1748360       405  5000333       11    31/12/2023
# 1748360  1748361       405  5003637       32    31/12/2023
# 1748361  1748362       157  5001209      124    31/12/2023
# 1748362  1748363       157  5001073       22    31/12/2023
#
# [1748363 rows x 5 columns]

# %%
sala = carrega_tabela("bilheteria.db","sala")
sala
# Out:
#            id                                         nome  from_complexo
# 0     5000056  KINOPLEX IGUAÇU TOP SALA 01 - KINOEVOLUTION           2387
# 1     5000057                  KINOPLEX IGUAÇU TOP SALA 02           2387
# 2     5000058                  KINOPLEX IGUAÇU TOP SALA 03           2387
# 3     5000061                   SALA KINOPLEX MADUREIRA 01           2389
# 4     5000062                   SALA KINOPLEX MADUREIRA 02           2389
# ...       ...                                          ...            ...
# 3226  5007071                         MULTICINE SÃO JOSÉ 2          55466
# 3227  5007072                         MULTICINE SÃO JOSÉ 3          55466
# 3228  5007073                         MULTICINE SÃO JOSÉ 4          55466
# 3229  5007075                        CINE RITZ MONLEVADE 1          55563
# 3230  5007076                        CINE RITZ MONLEVADE 2          55563
#
# [3231 rows x 3 columns]

# %%
filme = carrega_tabela("bilheteria.db","filme")
filme
# Out:
#       id                                 titulo_original  \
# 0      1                                   DURVAL DISCOS
# 1      2                                       NOSSO LAR
# 2      3                                         REMOÇÃO
# 3      4                    HOJE EU QUERO VOLTAR SOZINHO
# 4      5                          O HOMEM DE LAGOA SANTA
# ..   ...                                             ...
# 510  511             NCT NATION: TO THE WORLD IN CINEMAS
# 511  512                            JOURNEY TO BETHLEHEM
# 512  513                                       PRISCILLA
# 513  514  SEVENTEEN TOUR 'FOLLOW' TO JAPAN: LIVE VIEWING
# 514  515                                      THE CHOSEN
#
#                                              titulo_br         cpb_roe  \
# 0                                                 None  B0200001000000
# 1                                                 None  B1001259400000
# 2                                                 None  B1301918400000
# 3                                                 None  B1402094700000
# 4                                                 None  B1500150500000
# ..                                                 ...             ...
# 510                NCT NATION: TO THE WORLD IN CINEMAS  E2300498800000
# 511                                 JORNADA PARA BELEM  E2300507800000
# 512                                          PRISCILLA  E2300508800000
# 513     SEVENTEEN TOUR 'FOLLOW' TO JAPAN: LIVE VIEWING  E2300549400000
# 514  THE CHOSEN - OS ESCOLHIDOS - TEMPORADA 4 - PAR...  E2400165700000
#
#         pais_origem  from_distribuidora
# 0            BRASIL                  24
# 1            BRASIL                   3
# 2            BRASIL                  51
# 3            BRASIL                  24
# 4            BRASIL                  40
# ..              ...                 ...
# 510   CORÉIA DO SUL                  52
# 511  ESTADOS UNIDOS                  72
# 512  ESTADOS UNIDOS                   1
# 513   CORÉIA DO SUL                  28
# 514  ESTADOS UNIDOS                  58
#
# [515 rows x 6 columns]

# %%
complexo = carrega_tabela("bilheteria.db","complexo")
complexo
# Out:
#         id            municipio  UF  from_exibidor
# 0      438       BELO HORIZONTE  MG            437
# 1      895            SÃO PAULO  SP           1843
# 2      896          SANTO ANDRÉ  SP           1843
# 3      897            SÃO PAULO  SP           1843
# 4      898            SÃO PAULO  SP           1843
# ..     ...                  ...  ..            ...
# 678  55214        VÁRZEA GRANDE  MT           2379
# 679  55217  VALPARAÍSO DE GOIÁS  GO           2379
# 680  55428  SÃO JOSÉ DOS CAMPOS  SP          15263
# 681  55466             SÃO JOSÉ  SC           5935
# 682  55563       JOÃO MONLEVADE  MG          55562
#
# [683 rows x 4 columns]

# %% [markdown]
# # 10 Filmes com mais e menos bilheteria

# %%
# Agrupamos por filme e somamos a bilheteria de cada filme, obtendo a bilheteria total
filme_bilhe = sessao.groupby("filme_id")["publico"].sum().reset_index()
#Contamos a quantidade de sessoes de cada filme
filme_sessoes = sessao["filme_id"].value_counts().reset_index()
#coluna intermediara para juntar cada filme_id com seu titulo original, junto com a bilheteria total e o numero de sessoes total
filme_nome = filme[["id","titulo_original"]].rename(columns={"id":"filme_id"})

#juntamos tudo numa so tabela
filmes_total = pd.merge(filme_bilhe, filme_sessoes).merge(filme_nome).rename(columns={"count":"numero_sessoes","publico":"bilheteria_total"})

#organizamos os valores de acordo com a bilheteria, os 10 primeiros sao os de maior bilheteria enquanto os 10 ultimos os de menor
filmes10_com_menor_bilheteria = filmes_total.sort_values(by="bilheteria_total").head(10)
filmes10_com_maior_bilheteria = filmes_total.sort_values(by="bilheteria_total", ascending=False).head(10)

# %%
filmes10_com_maior_bilheteria
# Out:
#      filme_id  bilheteria_total  numero_sessoes  \
# 398       399          10238598           56364
# 323       324           6235953           64425
# 328       329           6132354           50614
# 268       269           5631389           65808
# 255       256           5358525           70676
# 362       363           4211764           40509
# 359       360           3987722           41205
# 388       389           3985017           49623
# 343       344           3328797           36391
# 454       455           2839181           36641
#
#                          titulo_original
# 398                               BARBIE
# 323          THE SUPER MARIO BROS. MOVIE
# 328                               FAST X
# 268             AVATAR: THE WAY OF WATER
# 255         PUSS IN BOOTS: THE LAST WISH
# 362       GUARDIANS OF THE GALAXY VOL. 3
# 359                   THE LITTLE MERMAID
# 388                            ELEMENTAL
# 343  SPIDER-MAN: ACROSS THE SPIDER-VERSE
# 454                            THE NUN 2

# %%
filmes10_com_menor_bilheteria
# Out:
#      filme_id  bilheteria_total  numero_sessoes            titulo_original
# 257       258                 1               1         UNE FEMME DU MONDE
# 33         34                 3               2        PEQUENOS GUERREIROS
# 46         47                 4               2              BALA SEM NOME
# 222       223                 5               1                THE ROUNDUP
# 243       244                 5               2                WHITE NOISE
# 9          10                 5               4                    MIRANTE
# 199       200                 7               1  DEMON SLAYER: MUGEN TRAIN
# 32         33                 8               1     MIÚDA E O GUARDA-CHUVA
# 239       240                 8               2                     FOURMI
# 25         26                 9               1      ALÉM DA LENDA - FILME

# %% [markdown]
# # Numero de bilheteria por dia

# %%
bilheteria_por_dia = sessao.groupby("data_exibicao")["publico"].sum().reset_index()

bilheteria_por_dia["data_exibicao"] = pd.to_datetime(bilheteria_por_dia["data_exibicao"], format="%d/%m/%Y")
bilheteria_por_dia = bilheteria_por_dia.sort_values(by="data_exibicao").reset_index(drop=True)
bilheteria_por_dia
# Out:
#     data_exibicao  publico
# 0      2023-01-01   129090
# 1      2023-01-02   441783
# 2      2023-01-03   399118
# 3      2023-01-04   442166
# 4      2023-01-05   335396
# ..            ...      ...
# 360    2023-12-27   323521
# 361    2023-12-28   338424
# 362    2023-12-29   266269
# 363    2023-12-30   276873
# 364    2023-12-31    19327
#
# [365 rows x 2 columns]

# %%
#MAXIMO DE CADA MES
#Janeiro 
print(bilheteria_por_dia[bilheteria_por_dia.publico == bilheteria_por_dia[0:31]["publico"].max()])
#Fevereiro
print(bilheteria_por_dia[bilheteria_por_dia.publico == bilheteria_por_dia[32:61]["publico"].max()])
#Abril 
print(bilheteria_por_dia[bilheteria_por_dia.publico == bilheteria_por_dia[90:120]["publico"].max()])
#Maio
print(bilheteria_por_dia[bilheteria_por_dia.publico == bilheteria_por_dia[121:151]["publico"].max()])
#Junho 
print(bilheteria_por_dia[bilheteria_por_dia.publico == bilheteria_por_dia[151:181]["publico"].max()])
#agosto
print(bilheteria_por_dia[bilheteria_por_dia.publico == bilheteria_por_dia[213:243]["publico"].max()])
#setembro
print(bilheteria_por_dia[bilheteria_por_dia.publico == bilheteria_por_dia[243:273]["publico"].max()])
# Out:
#   data_exibicao  publico
# 6    2023-01-07   579502
#    data_exibicao  publico
# 41    2023-02-11   842227
#    data_exibicao  publico
# 97    2023-04-08   726990
#     data_exibicao  publico
# 139    2023-05-20   881420
#     data_exibicao  publico
# 158    2023-06-08   822573
#     data_exibicao  publico
# 216    2023-08-05   640137
#     data_exibicao  publico
# 272    2023-09-30   683916

# %%
# datas = pd.date_range(start="2023-01-01", periods=365)
plt.figure(figsize=(16,5))
plt.plot(range(1,366),bilheteria_por_dia["publico"], color="burlywood")
#213
#274
dias_inicio_mes = [1, 7, 32, 42, 60, 91, 98, 121, 140, 152, 159, 182, 201, 217, 244, 273, 305, 335]
nomes_meses = ["Jan", "7", "Fev", "11", "Mar", "Abr","8", "Mai", "20", "Jun", "8", "Jul","20", "Ago", "Set", "Out","Nov", "Dez"]

plt.xticks(ticks=dias_inicio_mes, labels=nomes_meses)
plt.grid()

plt.ylabel("Bilheteria Total")
plt.show()

#20 de julho se estreiou Barbie
#01 de junho se estreiou Spiderman Acros spider verse
#05 de Abril tinha saido Super Mario Bros o Filme so que era quarta feira,
#o dia 10 e 11 de fevereiro que foram os dias pico, os filmes mais assistidos foram Gato de Botas 2, Megan e Avatar
#Que ja tinham sido estreiados faz um mes mais ou menos, mas parece que com o inicio do ano as pessoas demoraram ate
# colocarse em dias

# %% [markdown]
# # Numero de bilheteria por dia da semana

# %%
sessao = carrega_tabela("bilheteria.db","sessao")

# %%
dias_ano_dataframe = sessao.groupby("data_exibicao")["publico"].sum().reset_index()
dias_ano_dataframe["data_exibicao"] = pd.to_datetime(dias_ano_dataframe["data_exibicao"], format="%d/%m/%Y")

dias_ano_dataframe = dias_ano_dataframe.sort_values(by="data_exibicao").reset_index(drop=True)
dias_ano_dataframe["dias_da_semana"] = dias_ano_dataframe["data_exibicao"].dt.day_name(locale="pt_BR")
bilheteria_por_dia_da_semana = dias_ano_dataframe.groupby("dias_da_semana")["publico"].sum().reset_index()
bilheteria_por_dia_da_semana.sort_values(by="dias_da_semana")

ordem_correta = [
    "Segunda feira", "Terça feira", "Quarta feira",
    "Quinta feira", "Sexta feira", "Sábado", "Domingo"
]

# Transformar a coluna em categórica com ordem personalizada
bilheteria_por_dia_da_semana['dias_da_semana'] = pd.Categorical(
    bilheteria_por_dia_da_semana['dias_da_semana'],
    categories=ordem_correta,
    ordered=True
    )

# Ordenar
bilheteria_por_dia_da_semana = bilheteria_por_dia_da_semana.sort_values('dias_da_semana')
bilheteria_por_dia_da_semana
# Out:
#   dias_da_semana   publico
# 3  Segunda feira  12967483
# 6    Terça feira  11495747
# 1   Quarta feira  12196203
# 2   Quinta feira  14209315
# 4    Sexta feira  14387832
# 5         Sábado  24541051
# 0        Domingo  20355452

# %%
dias_da_semana = ["Segunda","Terça","Quarta","Quinta","Sexta","Sabado","Domingo"]

plt.figure(figsize=(10,5))

plt.bar(dias_da_semana, bilheteria_por_dia_da_semana["publico"], color="burlywood")
plt.ylabel("Bilheteria")
plt.show()

# %% [markdown]
# # Numero de sessoes por dia

# %%
#quantidade de sessoes por dia
sessoes_dia = sessao.groupby("data_exibicao").size().reset_index()
sessoes_dia["data_exibicao"] = pd.to_datetime(sessoes_dia["data_exibicao"], format="%d/%m/%Y")
sessoes_dia = sessoes_dia.sort_values(by="data_exibicao")
sessoes_dia[0]
# Out:
# 0      3119
# 12     4255
# 24     4301
# 36     4298
# 48     4478
#        ...
# 323    4021
# 335    4280
# 346    4198
# 357    4224
# 364    1365
# Name: 0, Length: 365, dtype: int64

# %%
plt.figure(figsize=(15,5))
plt.plot(range(1,366),sessoes_dia[0], color="burlywood")

dias_inicio_mes = [1, 32, 60, 91, 121, 152, 182, 213, 244, 274, 305, 335]
nomes_meses = ["Jan", "Fev", "Mar", "Abr", "Mai", "Jun", "Jul", "Ago", "Set", "Out","Nov", "Dez"]

plt.xticks(ticks=dias_inicio_mes, labels=nomes_meses)
plt.grid()

plt.ylabel("Sessões")
plt.show()

# %% [markdown]
# # Numero de bilheteria por mes

# %%
bilheteria_por_dia = sessao.groupby("data_exibicao")["publico"].sum().reset_index()

# Converter para datetime
bilheteria_por_dia["data_exibicao"] = pd.to_datetime(
    bilheteria_por_dia["data_exibicao"], format="%d/%m/%Y"
)

# Ordenar
bilheteria_por_dia = bilheteria_por_dia.sort_values(by="data_exibicao").reset_index(drop=True)

# Agrupar por mês (como Period)
bilheteria_por_dia["mes"] = bilheteria_por_dia["data_exibicao"].dt.to_period("M")

# Agrupar e renomear
bilheteria_por_mes = bilheteria_por_dia.groupby("mes")["publico"].sum().reset_index()

bilheteria_por_mes
# Out:
#         mes   publico
# 0   2023-01   9922607
# 1   2023-02   8087999
# 2   2023-03   5781219
# 3   2023-04   9694592
# 4   2023-05  12008632
# 5   2023-06  10838998
# 6   2023-07  17739155
# 7   2023-08   7682475
# 8   2023-09   6807769
# 9   2023-10   9158840
# 10  2023-11   6238417
# 11  2023-12   6192380

# %%
dias_da_semana = ["Jan", "Fev", "Mar", "Abr", "Mai", "Jun", "Jul", "Ago", "Set", "Out","Nov", "Dez"]

plt.figure(figsize=(10,5))

plt.bar(dias_da_semana, bilheteria_por_mes["publico"], color="burlywood")
plt.ylabel("Bilheteria")
plt.show()

# %% [markdown]
# # Vida dos filmes em relacao a bilheteria

# %%
dias_totais = pd.date_range(start="2023-01-01", end="2023-12-31", freq="D")

#Esta funcao retorna um dataframe com o publico total de todas as sessoes de cada dia de um filme
def filme_por_dia(id_do_filme):
    data_frame = sessao[sessao.filme_id == id_do_filme].copy() #todas as linhas que possuem essa id na tabela sessao
    data_frame["data_exibicao"] = pd.to_datetime( #convertemos para tipo data as datas
        data_frame["data_exibicao"],
        format="%d/%m/%Y"
        )
    data_frame = data_frame.groupby("data_exibicao")["publico"].sum() #agrupamos por data de exibicao e somamos o publico
    data_frame = data_frame[data_frame >= data_frame.max()/100] #filtramos as linhas que possuam um publico maior a 1% do maximo
    data_frame = data_frame.reindex(dias_totais) #reindexamos com os 365 dias do ano para ter um index continuo
    return data_frame

#funciona de forma analoga a funcao anterior com a unica diferenca de retornar o tamanho do dataframe
#mas nesse contexto o tamanho do dataframe quer dizer quantos dias um filme teve publico maior ao 1% do seu publico maximo
def dias_totais_com_publico(id_do_filme):
    data_frame = sessao[sessao.filme_id == id_do_filme].copy()
    data_frame.data_exibicao = pd.to_datetime(data_frame.data_exibicao, format="%d/%m/%Y")
    data_frame = data_frame.groupby("data_exibicao")["publico"].sum()
    data_frame = data_frame[data_frame >= data_frame.max()/100]
    return len(data_frame)

dias_totais_com_publico(256)
# Out:
# 85

# %%
tempos_de_vida = []

for filme_id in filme["id"]:
    tempos_de_vida.append(dias_totais_com_publico(filme_id))
    tempos_de_vida.sort()

contagem = {}
for numero_dias in tempos_de_vida:
    contagem[numero_dias] = contagem.get(numero_dias, 0) + 1

media = np.mean(tempos_de_vida)
mediana = np.median(tempos_de_vida)
moda = max(set(tempos_de_vida), key=tempos_de_vida.count)

print("A media de tempo de vida por publico é:", media)
print("A mediana de tempo de vida por publico é:", mediana)
print("A moda de tempo de vida por publico é:", moda)
# Out:
# A media de tempo de vida por publico é: 20.89902912621359
# A mediana de tempo de vida por publico é: 16.0
# A moda de tempo de vida por publico é: 14

# %%
# Calcular as métricas
media = np.mean(tempos_de_vida)
mediana = np.median(tempos_de_vida)
moda = max(set(tempos_de_vida), key=tempos_de_vida.count)

# Criar o gráfico
plt.figure(figsize=(10, 5))
plt.bar(contagem.keys(), contagem.values(), color="burlywood")

# Adicionar linhas verticais
plt.axvline(moda, color='red', linestyle='--', label=f'Moda ({moda} dias)')
plt.axvline(mediana, color='orange', linestyle='--', label=f'Mediana ({mediana} dias)')
plt.axvline(media, color='green', linestyle='--', label=f'Média ({media:.1f} dias)')

# Configurações finais
plt.xlabel('Dias')
plt.ylabel('Frequência')
plt.legend(fontsize=14)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(16,8))
r = range(1,366)
for filmes,nome in filmes10_com_maior_bilheteria[["filme_id","titulo_original"]].values:
    plt.plot(r, filme_por_dia(filmes),label=nome,linewidth=1)

plt.legend(fontsize=14)
dias_inicio_mes = [1, 32, 60, 91, 121, 152, 182, 213, 244, 274, 305, 335]
nomes_meses = ["Jan", "Fev", "Mar", "Abr", "Mai", "Jun", "Jul", "Ago", "Set", "Out","Nov", "Dez"]

plt.ylabel("Bilheteria")
plt.xticks(ticks=dias_inicio_mes, labels=nomes_meses)
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Vida dos filmes em relacao a sessoes

# %%
#quantidade de sessoes por dia por filme
sessoes_dia = (
    sessao.groupby(["data_exibicao","filme_id"])["filme_id"] #agrupamos por data e id
    .value_counts() #da coluna filme_id contamos quantas vezes se repete cada valor
    .reset_index() #reiniciamos o index para que data_exibicao volte a ser uma coluna
    )
sessoes_dia["data_exibicao"] = pd.to_datetime(sessoes_dia["data_exibicao"], format="%d/%m/%Y")

sessoes_dia = sessoes_dia.sort_values(by="data_exibicao").reset_index(drop=True)
sessoes_dia = sessoes_dia.set_index("data_exibicao")

sessoes_dia
# Out:
#                filme_id  count
# data_exibicao
# 2023-01-01           25      1
# 2023-01-01          281      5
# 2023-01-01          279     12
# 2023-01-01          269   1612
# 2023-01-01          259    378
# ...                 ...    ...
# 2023-12-31          158      1
# 2023-12-31          157      2
# 2023-12-31           91      1
# 2023-12-31          459    475
# 2023-12-31          513      2
#
# [14474 rows x 2 columns]

# %%
dias_totais = pd.date_range(start="2023-01-01", end="2023-12-31", freq="D")

def sessoes_por_dia(filme_id):
    dataframe = sessoes_dia[sessoes_dia["filme_id"]==filme_id]
    dataframe = dataframe.reindex(dias_totais)
    dataframe = dataframe[dataframe >= dataframe.max()/100]
    return dataframe["count"]

def dias_totais_com_sessoes(filme_id):
    dataframe = sessoes_dia[sessoes_dia["filme_id"] == filme_id] #recebe os dias em que o filme teve sesoes
    dataframe = dataframe[dataframe >= dataframe.max()/100]       #tira os dias em que a quantidade se sessoes foi menor a 1% do maximo
    dataframe = dataframe.dropna()                               #remove as linhas nulas
    return dataframe.shape[0]                                    #retorna o numero de linhas do dataframe

dias_totais_com_sessoes(1)
# Out:
# 15

# %%
tempos_de_vida_sessao = []
for filme_id in filme["id"].values:
    tempos_de_vida_sessao.append(dias_totais_com_sessoes(filme_id))
tempos_de_vida_sessao.sort()

contagem = {}
for cada_tempo_de_vida in tempos_de_vida_sessao:
    contagem[cada_tempo_de_vida] = contagem.get(cada_tempo_de_vida, 0) + 1

#media
media = np.mean(tempos_de_vida_sessao)
modiana = np.median(tempos_de_vida_sessao)
moda = max(set(tempos_de_vida_sessao),key=tempos_de_vida_sessao.count)


print(f"A media do tempo de vida é: {media}")
print(f"A mediana do tempo de vida é: {mediana}")
print(f"A moda do tempo de vida é: {moda}")
# Out:
# A media do tempo de vida é: 23.681553398058252
# A mediana do tempo de vida é: 16.0
# A moda do tempo de vida é: 14

# %%
media = np.mean(tempos_de_vida_sessao)
modiana = np.median(tempos_de_vida_sessao)
moda = max(set(tempos_de_vida_sessao),key=tempos_de_vida_sessao.count)

plt.figure(figsize=(10,5))
plt.bar(contagem.keys(), contagem.values(), color="burlywood")

plt.axvline(moda, color='red', linestyle='--', label=f'Moda ({moda} dias)')
plt.axvline(mediana, color='orange', linestyle='--', label=f'Mediana ({mediana} dias)')
plt.axvline(media, color='green', linestyle='--', label=f'Média ({media:.1f} dias)')

plt.xlabel('Dias')
plt.ylabel('Frequência')
plt.legend(fontsize=14)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(16,6))
r = range(1,366)

for filmes,nome in filmes10_com_maior_bilheteria[["filme_id","titulo_original"]].values:
    plt.plot(r, sessoes_por_dia(filmes),label=nome,linewidth=1)

plt.legend(
    loc='center left',
    bbox_to_anchor=(0.75, 0.8),  # empurra para a direita
    fontsize=13
)
dias_inicio_mes = [1, 32, 60, 91, 121, 152, 182, 213, 244, 274, 305, 335]
nomes_meses = ["Jan", "Fev", "Mar", "Abr", "Mai", "Jun", "Jul", "Ago", "Set", "Out","Nov", "Dez"]

plt.ylabel("Numero de Sessões")
plt.xticks(ticks=dias_inicio_mes, labels=nomes_meses)
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Diferenca do tempo de vida por sessoes menos o tempo de vida por publico de cada filme

# %%
filme = carrega_tabela("bilheteria.db","filme")
filme = filme[["id","titulo_original"]]

filme["vida_sessoes"] = filme["id"].apply(dias_totais_com_sessoes)
filme["vida_bilheteria"] = filme["id"].apply(dias_totais_com_publico)
filme["diferenca"] = filme["vida_sessoes"] - filme["vida_bilheteria"]
filme
# Out:
#       id                                 titulo_original  vida_sessoes  \
# 0      1                                   DURVAL DISCOS            15
# 1      2                                       NOSSO LAR            11
# 2      3                                         REMOÇÃO            10
# 3      4                    HOJE EU QUERO VOLTAR SOZINHO             1
# 4      5                          O HOMEM DE LAGOA SANTA            12
# ..   ...                                             ...           ...
# 510  511             NCT NATION: TO THE WORLD IN CINEMAS             3
# 511  512                            JOURNEY TO BETHLEHEM            15
# 512  513                                       PRISCILLA            11
# 513  514  SEVENTEEN TOUR 'FOLLOW' TO JAPAN: LIVE VIEWING             1
# 514  515                                      THE CHOSEN            18
#
#      vida_bilheteria  diferenca
# 0                 15          0
# 1                  9          2
# 2                 10          0
# 3                  1          0
# 4                 11          1
# ..               ...        ...
# 510                3          0
# 511               15          0
# 512               11          0
# 513                1          0
# 514               17          1
#
# [515 rows x 5 columns]

# %%
# filme.groupby("diferenca")["diferenca"].value_counts()
media_diferenca = float(np.mean(filme["diferenca"]))
media_diferenca
# Out:
# 2.78252427184466

# %% [markdown]
# # Tabelas

# %%
def questao_5(database):
    #carregamos as tabelas necessárias
    sessao = carrega_tabela(database, "sessao")
    filme = carrega_tabela(database, "filme")
    complexo = carrega_tabela(database, "complexo")
    sala = carrega_tabela(database, "sala")

    '''a partir daqui, renomearemos as colunas selecionadas das tabelas sala, complexo e filme 
    para que tenham o mesmo nome entre elas e as escolhidas da tabela sessao, a fim de poder fazer merge entre elas. '''
    #a partir da tabela sala, selecionamos as colunas id e from_complexo, renomeando-as para, respectivamente, sala_id e cidade_id
    sala_id__cidade__id = (
        sala[["id", "from_complexo"]]
        .rename(columns={"id":"sala_id","from_complexo":"cidade_id"})
        )
    
    #a partir da tabela complexo, selecionamos as colunas id e municipio, renomeando-as para, respectivamente, cidade_id e cidade
    cidade_id__cidade = (
        complexo[["id", "municipio"]]
        .rename(columns={"id":"cidade_id","municipio":"cidade"})
        )
    
    #a partir da tabela sessao, selecionamos as colunas sala_id, filme_id e publico
    #agrupamos esta última tabela por sala_id e filme_id semelhantes, somando o público total de cada sala para cada filme
    sala_id__filme_id__publico_total = (
        sessao[["filme_id","sala_id","publico"]]
        .groupby(["sala_id","filme_id"])
        .sum()
        .reset_index()
        )
    
    #a partir da tabela filme, selecionamos as colunas id, titulo_original e pais_origem, renomeando a primeira para filme_id
    filme_id__titulo_original__pais_origem = (
        filme[["id", "titulo_original", "pais_origem"]]
        .rename(columns={"id":"filme_id"})
        )
    
    #merges
    sala_id__filme_id__publico_total__titulo = (
        sala_id__filme_id__publico_total
        .merge(filme_id__titulo_original__pais_origem, how="left", on="filme_id")
        )
    
    sala_id__cidade_id__cidade = (
        sala_id__cidade__id
        .merge(cidade_id__cidade, how="left", on="cidade_id")
        )

    sala_id__titulo_original__publico_total__pais_origem__cidade = (
        sala_id__filme_id__publico_total__titulo[["sala_id","titulo_original","publico","pais_origem"]]
        .merge(sala_id__cidade_id__cidade[["sala_id","cidade"]], how="left", on="sala_id")
        )
    
    #agrupamos por cidade e pais_origem, somando o público total de cada cidade por país que lançou os filmes citados no database
    cidade__pais_origem__publico = (
        sala_id__titulo_original__publico_total__pais_origem__cidade[["cidade", "pais_origem","publico"]]
        .groupby(["cidade","pais_origem"])
        .sum("publico")
        .reset_index()
        )
    
    #da tabela criada imediatamente acima, criamos esta aqui, escolhendo apenas as linhas cujos públicos por cidade sejam referentes a filmes brasileiros
    #resetamos o index
    #renomeamos as colunas para os nomes pedidos pela questão
    cidade__bilheteria_br = (
        cidade__pais_origem__publico
        .loc[cidade__pais_origem__publico["pais_origem"] == "BRASIL"]
        [["cidade","publico"]]
        .reset_index(drop=True)
        .rename(columns={"cidade":"CIDADE","publico":"BILHETERIA_BR"})
        
        )
    
    #aqui, pelo mesmo processo, criamos uma tabela escolhendo as linhas cujos públicos por cidade sejam referentes a filmes estrangeiros
    cidade__bilheteria_estrangeira = (
        cidade__pais_origem__publico
        .loc[cidade__pais_origem__publico["pais_origem"] != "BRASIL"]
        [["cidade","publico"]]
        .groupby("cidade")
        .sum("publico")
        .reset_index()
        .rename(columns={"cidade":"CIDADE","publico":"BILHETERIA_ESTRANGEIRA"})
    )

    #merge das tabelas sobre bilheterias brasileira e estrangeira
    cidade__bilheteria_br__bilheteria_estrangeira = (
        cidade__bilheteria_br.merge(cidade__bilheteria_estrangeira, how="left", on="CIDADE")
    )

    cidade__bilheteria_br__bilheteria_estrangeira["BILHETERIA_BR"] = (
        cidade__bilheteria_br__bilheteria_estrangeira["BILHETERIA_BR"]
        .fillna(0) #preenche valores nulos com 0
        .astype("Int64") #converte para tipo long-int, que permite realizar cálculos com valores inteiros de maior tamanho que o suportado pelo tipo int32 ou int.
    )

    #retorna o DataFrame com a bilheteria brasileira em ordem decrescente e com o index reiniciado
    return cidade__bilheteria_br__bilheteria_estrangeira.sort_values(ascending=False, by="BILHETERIA_ESTRANGEIRA").reset_index(drop=True)
questao_5("bilheteria.db")
# Out:
#                      CIDADE  BILHETERIA_BR  BILHETERIA_ESTRANGEIRA
# 0                 SÃO PAULO         403251              12907219.0
# 1            RIO DE JANEIRO         546789               7949517.0
# 2                  BRASÍLIA          80122               3192315.0
# 3                  CURITIBA          46382               2918732.0
# 4            BELO HORIZONTE          98746               2910668.0
# ..                      ...            ...                     ...
# 334              MOGI-GUACU            598                  1373.0
# 335          JOÃO MONLEVADE            252                  1200.0
# 336           CÓRREGO FUNDO            123                     NaN
# 337                   PAINS             72                     NaN
# 338  SANTO ANTÔNIO DO MONTE            126                     NaN
#
# [339 rows x 3 columns]

# %%
def questao_5(database):
    #carregamos as tabelas necessárias
    sessao = carrega_tabela(database, "sessao")
    filme = carrega_tabela(database, "filme")
    complexo = carrega_tabela(database, "complexo")
    sala = carrega_tabela(database, "sala")

    '''a partir daqui, renomearemos as colunas selecionadas das tabelas sala, complexo e filme 
    para que tenham o mesmo nome entre elas e as escolhidas da tabela sessao, a fim de poder fazer merge entre elas. '''
    #a partir da tabela sala, selecionamos as colunas id e from_complexo, renomeando-as para, respectivamente, sala_id e cidade_id
    sala_id__cidade__id = (
        sala[["id", "from_complexo"]]
        .rename(columns={"id":"sala_id","from_complexo":"cidade_id"})
        )
    
    #a partir da tabela complexo, selecionamos as colunas id e municipio, renomeando-as para, respectivamente, cidade_id e cidade
    cidade_id__cidade = (
        complexo[["id", "municipio"]]
        .rename(columns={"id":"cidade_id","municipio":"cidade"})
        )
    
    #a partir da tabela sessao, selecionamos as colunas sala_id, filme_id e publico
    #agrupamos esta última tabela por sala_id e filme_id semelhantes, somando o público total de cada sala para cada filme
    sala_id__filme_id__publico_total = (
        sessao[["filme_id","sala_id","publico"]]
        .groupby(["sala_id","filme_id"])
        .sum()
        .reset_index()
        )
    
    #a partir da tabela filme, selecionamos as colunas id, titulo_original e pais_origem, renomeando a primeira para filme_id
    filme_id__titulo_original__pais_origem = (
        filme[["id", "titulo_original", "pais_origem"]]
        .rename(columns={"id":"filme_id"})
        )
    
    #merges
    sala_id__filme_id__publico_total__titulo = (
        sala_id__filme_id__publico_total
        .merge(filme_id__titulo_original__pais_origem, how="left", on="filme_id")
        )
    
    sala_id__cidade_id__cidade = (
        sala_id__cidade__id
        .merge(cidade_id__cidade, how="left", on="cidade_id")
        )

    sala_id__titulo_original__publico_total__pais_origem__cidade = (
        sala_id__filme_id__publico_total__titulo[["sala_id","titulo_original","publico","pais_origem"]]
        .merge(sala_id__cidade_id__cidade[["sala_id","cidade"]], how="left", on="sala_id")
        )
    
    #agrupamos por cidade e pais_origem, somando o público total de cada cidade por país que lançou os filmes citados no database
    cidade__pais_origem__publico = (
        sala_id__titulo_original__publico_total__pais_origem__cidade[["cidade", "pais_origem","publico"]]
        .groupby(["cidade","pais_origem"])
        .sum("publico")
        .reset_index()
        )
    
    #da tabela criada imediatamente acima, criamos esta aqui, escolhendo apenas as linhas cujos públicos por cidade sejam referentes a filmes brasileiros
    #resetamos o index
    #renomeamos as colunas para os nomes pedidos pela questão
    cidade__bilheteria_br = (
        cidade__pais_origem__publico
        .loc[cidade__pais_origem__publico["pais_origem"] == "BRASIL"]
        [["cidade","publico"]]
        .reset_index(drop=True)
        .rename(columns={"cidade":"CIDADE","publico":"BILHETERIA_BR"})
        
        )
    
    #aqui, pelo mesmo processo, criamos uma tabela escolhendo as linhas cujos públicos por cidade sejam referentes a filmes estrangeiros
    cidade__bilheteria_estrangeira = (
        cidade__pais_origem__publico
        .loc[cidade__pais_origem__publico["pais_origem"] != "BRASIL"]
        [["cidade","publico"]]
        .groupby("cidade")
        .sum("publico")
        .reset_index()
        .rename(columns={"cidade":"CIDADE","publico":"BILHETERIA_ESTRANGEIRA"})
    )

    #merge das tabelas sobre bilheterias brasileira e estrangeira
    cidade__bilheteria_br__bilheteria_estrangeira = (
        cidade__bilheteria_br.merge(cidade__bilheteria_estrangeira, how="right", on="CIDADE")
    )

    cidade__bilheteria_br__bilheteria_estrangeira["BILHETERIA_BR"] = (
        cidade__bilheteria_br__bilheteria_estrangeira["BILHETERIA_BR"]
        .fillna(0) #preenche valores nulos com 0
        .astype("Int64") #converte para tipo long-int, que permite realizar cálculos com valores inteiros de maior tamanho que o suportado pelo tipo int32 ou int.
    )

    #retorna o DataFrame com a bilheteria brasileira em ordem decrescente e com o index reiniciado
    return cidade__bilheteria_br__bilheteria_estrangeira.sort_values(ascending=True, by="BILHETERIA_BR").reset_index(drop=True)
questao_5("bilheteria.db").head(7)
# Out:
#         CIDADE  BILHETERIA_BR  BILHETERIA_ESTRANGEIRA
# 0        ASSIS              0                   23569
# 1    CANOINHAS              0                   19082
# 2         LINS              0                   18654
# 3   MARATAÍZES              0                   10691
# 4  JABOTICABAL              0                   16460
# 5      ITAPEVA              0                   19472
# 6   MONTENEGRO             76                   19609

# %%
def questao_5(database):
    #carregamos as tabelas necessárias
    sessao = carrega_tabela(database, "sessao")
    filme = carrega_tabela(database, "filme")
    complexo = carrega_tabela(database, "complexo")
    sala = carrega_tabela(database, "sala")

    '''a partir daqui, renomearemos as colunas selecionadas das tabelas sala, complexo e filme 
    para que tenham o mesmo nome entre elas e as escolhidas da tabela sessao, a fim de poder fazer merge entre elas. '''
    #a partir da tabela sala, selecionamos as colunas id e from_complexo, renomeando-as para, respectivamente, sala_id e cidade_id
    sala_id__cidade__id = (
        sala[["id", "from_complexo"]]
        .rename(columns={"id":"sala_id","from_complexo":"cidade_id"})
        )
    
    #a partir da tabela complexo, selecionamos as colunas id e municipio, renomeando-as para, respectivamente, cidade_id e cidade
    cidade_id__cidade = (
        complexo[["id", "municipio"]]
        .rename(columns={"id":"cidade_id","municipio":"cidade"})
        )
    
    #a partir da tabela sessao, selecionamos as colunas sala_id, filme_id e publico
    #agrupamos esta última tabela por sala_id e filme_id semelhantes, somando o público total de cada sala para cada filme
    sala_id__filme_id__publico_total = (
        sessao[["filme_id","sala_id","publico"]]
        .groupby(["sala_id","filme_id"])
        .sum()
        .reset_index()
        )
    
    #a partir da tabela filme, selecionamos as colunas id, titulo_original e pais_origem, renomeando a primeira para filme_id
    filme_id__titulo_original__pais_origem = (
        filme[["id", "titulo_original", "pais_origem"]]
        .rename(columns={"id":"filme_id"})
        )
    
    #merges
    sala_id__filme_id__publico_total__titulo = (
        sala_id__filme_id__publico_total
        .merge(filme_id__titulo_original__pais_origem, how="left", on="filme_id")
        )
    
    sala_id__cidade_id__cidade = (
        sala_id__cidade__id
        .merge(cidade_id__cidade, how="left", on="cidade_id")
        )

    sala_id__titulo_original__publico_total__pais_origem__cidade = (
        sala_id__filme_id__publico_total__titulo[["sala_id","titulo_original","publico","pais_origem"]]
        .merge(sala_id__cidade_id__cidade[["sala_id","cidade"]], how="left", on="sala_id")
        )
    return sala_id__titulo_original__publico_total__pais_origem__cidade.loc[sala_id__titulo_original__publico_total__pais_origem__cidade["cidade"] == "ASSIS"]
questao_5("bilheteria.db")
# Out:
#        sala_id                      titulo_original  publico     pais_origem  \
# 81190  5004202         PUSS IN BOOTS: THE LAST WISH     1578  ESTADOS UNIDOS
# 81191  5004202                                M3GAN      423  ESTADOS UNIDOS
# 81192  5004202                 JOHN WICK: CHAPTER 4      348  ESTADOS UNIDOS
# 81193  5004202             AVATAR: THE WAY OF WATER     1108  ESTADOS UNIDOS
# 81194  5004202    ANT-MAN AND THE WASP: QUANTUMANIA      556  ESTADOS UNIDOS
# 81195  5004202                       EVIL DEAD RISE      213  ESTADOS UNIDOS
# 81196  5004202                            SCREAM VI      621  ESTADOS UNIDOS
# 81197  5004202                  THE POPE´S EXORCIST      197  ESTADOS UNIDOS
# 81198  5004202          THE SUPER MARIO BROS. MOVIE     2527  ESTADOS UNIDOS
# 81199  5004202                               FAST X     2712  ESTADOS UNIDOS
# 81200  5004202  SPIDER-MAN: ACROSS THE SPIDER-VERSE      761  ESTADOS UNIDOS
# 81201  5004202                   THE LITTLE MERMAID      602  ESTADOS UNIDOS
# 81202  5004202                            THE FLASH      297  ESTADOS UNIDOS
# 81203  5004202                          EQUALIZER 3       98  ESTADOS UNIDOS
# 81204  5004202                          OPPENHEIMER      371  ESTADOS UNIDOS
# 81205  5004202                            ELEMENTAL      991  ESTADOS UNIDOS
# 81206  5004202                    THE EXPENDABLES 4       98  ESTADOS UNIDOS
# 81207  5004202                               BARBIE     4167  ESTADOS UNIDOS
# 81208  5004202                          BLUE BEETLE      258  ESTADOS UNIDOS
# 81209  5004202                            THE MEG 2      232  ESTADOS UNIDOS
# 81210  5004202                                WONKA      636  ESTADOS UNIDOS
# 81211  5004202                    ALL FUN AND GAMES      135  ESTADOS UNIDOS
# 81212  5004202                     SOUND OF FREEDOM      548  ESTADOS UNIDOS
# 81213  5004202                            THE NUN 2     1013  ESTADOS UNIDOS
# 81214  5004202               THE EXORCIST: BELIEVER      134  ESTADOS UNIDOS
# 81215  5004202              FIVE NIGHTS AT FREDDY'S     1819  ESTADOS UNIDOS
# 81216  5004202         AQUAMAN AND THE LOST KINGDOM      340  ESTADOS UNIDOS
# 81217  5004202                 TROLLS BAND TOGETHER      182  ESTADOS UNIDOS
# 81218  5004202         PAW PATROL: THE MIGHTY MOVIE      546          CANADÁ
# 81219  5004202           MY BIG FAT GREEK WEDDING 3       58  ESTADOS UNIDOS
#
#       cidade
# 81190  ASSIS
# 81191  ASSIS
# 81192  ASSIS
# 81193  ASSIS
# 81194  ASSIS
# 81195  ASSIS
# 81196  ASSIS
# 81197  ASSIS
# 81198  ASSIS
# 81199  ASSIS
# 81200  ASSIS
# 81201  ASSIS
# 81202  ASSIS
# 81203  ASSIS
# 81204  ASSIS
# 81205  ASSIS
# 81206  ASSIS
# 81207  ASSIS
# 81208  ASSIS
# 81209  ASSIS
# 81210  ASSIS
# 81211  ASSIS
# 81212  ASSIS
# 81213  ASSIS
# 81214  ASSIS
# 81215  ASSIS
# 81216  ASSIS
# 81217  ASSIS
# 81218  ASSIS
# 81219  ASSIS
